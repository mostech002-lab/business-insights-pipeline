-- %%
CREATE DATABASE FOOD_APP_DB;
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:01.927

-- %%
-- Out:
-- Msg 156, Level 15, State 1, Line 1
-- Incorrect syntax near the keyword 'DATABASE'.
-- Total execution time: 00:00:00.687
